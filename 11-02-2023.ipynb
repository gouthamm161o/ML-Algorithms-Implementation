# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
ds=pd.DataFrame(np.random.rand(10,4),index=pd.date_range('1/1/2000',periods=10),columns=list('ABCD'))

# %%
ds
# Out:
#                    A         B         C         D
# 2000-01-01  0.055011  0.587346  0.014591  0.056443
# 2000-01-02  0.945159  0.453989  0.087157  0.803856
# 2000-01-03  0.362289  0.873048  0.163764  0.867221
# 2000-01-04  0.280206  0.156902  0.775441  0.148137
# 2000-01-05  0.500334  0.219963  0.999155  0.071551
# 2000-01-06  0.493030  0.980881  0.145411  0.811537
# 2000-01-07  0.209400  0.552395  0.125855  0.325247
# 2000-01-08  0.948688  0.817042  0.711258  0.166544
# 2000-01-09  0.289602  0.427080  0.390814  0.245277
# 2000-01-10  0.022508  0.112125  0.408686  0.675364

# %%
ds.plot()
# Out:
# <AxesSubplot:>

# %%
ds.plot.bar()
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])

# %%
ds.plot()
# Out:
# <AxesSubplot:>

# %%
ds.plot.bar()
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds.plot.box()
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,6),columns=['A','B','C','D','E','F'])
ds.plot.box()
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,6),columns=['A','B','C','D','E','F'])
ds.plot.area()
# Out:
# <AxesSubplot:>

# %%
ds=pd.DataFrame(np.random.rand(10,6),columns=['A','B','C','D','E','F'])
ds.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
ds
# Out:
#           A         B         C         D         E         F
# 0  0.605373  0.071908  0.889658  0.089235  0.777433  0.789059
# 1  0.478716  0.310536  0.880620  0.586251  0.105091  0.084927
# 2  0.962652  0.281657  0.609462  0.249314  0.132287  0.511113
# 3  0.268526  0.708754  0.652271  0.289422  0.665829  0.877212
# 4  0.983567  0.748186  0.260087  0.894746  0.415972  0.059888
# 5  0.449523  0.814224  0.379351  0.840426  0.060070  0.299799
# 6  0.756072  0.714734  0.836576  0.985025  0.983825  0.200376
# 7  0.559693  0.365861  0.543565  0.982876  0.410797  0.415632
# 8  0.535654  0.465360  0.608495  0.558489  0.605622  0.599558
# 9  0.037860  0.950501  0.519327  0.618122  0.739166  0.617369

# %%
dt=pd.read_csv("C:\Users\Sai Goutham\Downloads\president_heights.csv")
# Out:
#   File "C:\Users\Sai Goutham\AppData\Local\Temp\ipykernel_8804\1344477762.py", line 1
#     dt=pd.read_csv("C:\Users\Sai Goutham\Downloads\president_heights.csv")
#                                                                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
ds=pd.read_csv("C:\Users\Sai Goutham\Downloads\CSV\president_heights.csv")
# Out:
#   File "C:\Users\Sai Goutham\AppData\Local\Temp\ipykernel_8804\2407135615.py", line 1
#     ds=pd.read_csv("C:\Users\Sai Goutham\Downloads\CSV\president_heights.csv")
#                                                                              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8804\1977025950.py in <module>
# ----> 1 ds
#
# NameError: name 'ds' is not defined

# %%
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8804\2369097233.py in <module>
# ----> 1 ds
#
# NameError: name 'ds' is not defined

# %%
dt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8804\284321914.py in <module>
# ----> 1 dt
#
# NameError: name 'dt' is not defined

# %%
data=[1,2,3,4,5]

# %%
data
# Out:
# [1, 2, 3, 4, 5]

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df[0][2]
# Out:
# 3

# %%
data1=['Shinchan',6],['Doraemon',12],['JJK',12],['Nobita',12]
df=pd.DataFrame(data1)

# %%
df
# Out:
#           0   1
# 0  Shinchan   6
# 1  Doraemon  12
# 2       JJK  12
# 3    Nobita  12

# %%
df.iloc[2]
# Out:
# 0    JJK
# 1     12
# Name: 2, dtype: object

# %%
df.iloc[0]
# Out:
# 0    Shinchan
# 1           6
# Name: 0, dtype: object

# %%
df[:][0:2:3]
# Out:
#           0  1
# 0  Shinchan  6

# %%
data1=['Shinchan',6],['Doraemon',12],['JJK',21],['Nobita',50]
df=pd.DataFrame(data1,columns=['Name','Age'])

# %%
df
# Out:
#        Name  Age
# 0  Shinchan    6
# 1  Doraemon   12
# 2       JJK   21
# 3    Nobita   50

# %%
import matplotlib.pyplot as plt

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
data1=['Shinchan',6,'Cartoon'],['Doraemon',12,'Cinema'],['JJK',12,'Cartoon'],['Nobita',12,'TV']
df=pd.DataFrame(data1,columns=['Name','Age','Department'])

# %%
df
# Out:
#        Name  Age Department
# 0  Shinchan    6    Cartoon
# 1  Doraemon   12     Cinema
# 2       JJK   12    Cartoon
# 3    Nobita   12         TV

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
data2={'Name':['Shinchan','Doraemon','Nobita','JJK','Its Me'],'Age':[1,5,10,21,32],'Dep':['Cartoon','TV','Movie','Tv','Bomma']}

# %%
df=pd.DataFrame(data2)

# %%
df
# Out:
#        Name  Age      Dep
# 0  Shinchan    1  Cartoon
# 1  Doraemon    5       TV
# 2    Nobita   10    Movie
# 3       JJK   21       Tv
# 4    Its Me   32    Bomma

# %%
data1=['Shinchan',6],['Doraemon',12],['JJK',12],['Nobita',12]
df=pd.DataFrame(data1)
df=pd.DataFrame(data2,index=['First','Second','Third','Fourth','Fifth'])

# %%
df
# Out:
#             Name  Age      Dep
# First   Shinchan    1  Cartoon
# Second  Doraemon    5       TV
# Third     Nobita   10    Movie
# Fourth       JJK   21       Tv
# Fifth     Its Me   32    Bomma

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>
